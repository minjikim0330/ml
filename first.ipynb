# %% [markdown]
# <a href="https://colab.research.google.com/github/minjikim0330/ml/blob/main/first.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 나의 두번째 코랩
# ## 실습내용
# - 실습1: Google의Colab으로첫번째파일생성
#
# - 실습2: Git레포지토리생성
#
# - 실습3:Colab제공기능으로github에업로드하기

# %% [markdown]
# ## 1. Hello world 출력
# -`print` 함수 사용
# ```python
# a= 1
# b= "프린트"
# print()
# print() # 프린트 하는 함수
# print()

# %%
print('hello world!')
# Out:
# hello world!

# %% [markdown]
# ## 2. Tensorflow 모듈 불러오기

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.19.0'
